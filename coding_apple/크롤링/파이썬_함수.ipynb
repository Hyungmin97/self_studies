# %%
print('안녕하세요 중고차 신뢰딜러 차은우입니다.')
# Out:
# 안녕하세요 중고차 신뢰딜러 차은우입니다.

# %%
#위의 코드를 중간중간 계속 출력해야한다?
#복잡하고 귀찮음

#위 긴 코드를 짧은 단어로 축약

# %%
def greet():
  print("안녕하세요 중고차 신뢰딜러 차은우입니다.")

# %%
greet()
# Out:
# 안녕하세요 중고차 신뢰딜러 차은우입니다.

# %%
#함수의 용도
#마법의 모자 만들기

# %%
def magic(hole):
  print(hole + 1)

# %%
magic(1)
# Out:
# 2

# %%
magic(12331)
# Out:
# 12332

# %%
#함수 실행하고 나서 가죽을 남기고 싶을 때,
def function():
  return 10

# %%
print(function())
# Out:
# 10

# %%
#구멍 여러개 만들 수 있음
def 구멍(구멍, 구멍2):
  print(구멍 + 구멍2)

# %%
구멍(1,2)
# Out:
# 3
