# %% [markdown]
# # 파일 쓰기(write 명령어)

# %%
file = open("/content/drive/MyDrive/Colab Notebooks/a.txt","w")

# %%
file.write('Hello')
# Out:
# 5

# %%
file.close()

# %% [markdown]
# # 파일 읽기(read 명령어)

# %%
file = open("/content/drive/MyDrive/Colab Notebooks/a.txt","r")

# %%
print(file.read())
# Out:
# Hello

# %%
file.close()

# %% [markdown]
# # 파일 추가(append 명령어)

# %%
file = open("/content/drive/MyDrive/Colab Notebooks/a.txt","a")

# %%
file.write("\n한국어: 반가워")
# Out:
# 9

# %%
file = open("/content/drive/MyDrive/Colab Notebooks/a.txt","r")

# %%
print(file.read())
# Out:
# Hello
# 한국어: 반가워

# %% [markdown]
# # binary 형식으로 파일을 작성하거나 읽기

# %%
file = open("/content/drive/MyDrive/Colab Notebooks/a.txt","wb")

# %% [markdown]
# # Excel 형식으로 파일 다루기

# %%
file = open("/content/drive/MyDrive/Colab Notebooks/data.csv","w")

# %%
file.write('김, 이, 박')
# Out:
# 7

# %%
file.write('\n김, 이, 박')
# Out:
# 8

# %%
file.close()

# %% [markdown]
# ##과제1.
# 리스트 = ['삼성전자', '카카오', '네이버', '신풍제약']
#
# 이런 리스트를 txt파일로 저장해보시오.

# %%
file = open("/content/drive/MyDrive/Colab Notebooks/list.txt","w")

# %%
file.write("리스트 = ['삼성전자', '카카오', '네이버', '신풍제약']")
# Out:
# 36

# %%
file.close()

# %% [markdown]
# ##과제2.
# 구구단을 2단부터 9단까지 결과부분만 출력하시오.

# %%
for i in range(2, 10):
  results = [i*j for j in range(1,10)]
  print(f"{i}단: {results}")
# Out:
# 2단: [2, 4, 6, 8, 10, 12, 14, 16, 18]
# 3단: [3, 6, 9, 12, 15, 18, 21, 24, 27]
# 4단: [4, 8, 12, 16, 20, 24, 28, 32, 36]
# 5단: [5, 10, 15, 20, 25, 30, 35, 40, 45]
# 6단: [6, 12, 18, 24, 30, 36, 42, 48, 54]
# 7단: [7, 14, 21, 28, 35, 42, 49, 56, 63]
# 8단: [8, 16, 24, 32, 40, 48, 56, 64, 72]
# 9단: [9, 18, 27, 36, 45, 54, 63, 72, 81]
