# %% [markdown]
# # 저번시간 숙제 (1)
#
#
#
# 리스트 = [ '삼성전자', '카카오', '네이버', '신풍제약' ] 이런 리스트가 하나 있습니다.
#
# Q. 이걸 다음 모양의 txt 파일로 저장하려면 어떻게 코드를 짜야할까요?

# %%
리스트 = ['삼성전자', '카카오', '네이버', '신충제약']

# %%
file = open('/content/drive/MyDrive/Colab Notebooks/코딩애플_크롤링/반복문_과제.txt', 'w')

# %%
#file.write(리스트[0] + '\n')
#file.write(리스트[1] + '\n')
#file.write(리스트[2] + '\n')
#file.write(리스트[3] + '\n')

# %%
for i in range(4):
  file.write(리스트[i]+'\n')

# %% [markdown]
# # Q. 구구단을 2단부터 9단까지 결과부분만 쭉 출력하고 싶으면 어떻게 코드를 짜야할까요?

# %%
for i in range(2,10):
  for j in range(1,10):
    print(i*j)
# Out:
# 2
# 4
# 6
# 8
# 10
# 12
# 14
# 16
# 18
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 4
# 8
# 12
# 16
# 20
# 24
# 28
# 32
# 36
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 6
# 12
# 18
# 24
# 30
# 36
# 42
# 48
# 54
# 7
# 14
# 21
# 28
# 35
# 42
# 49
# 56
# 63
# 8
# 16
# 24
# 32
# 40
# 48
# 56
# 64
# 72
# 9
# 18
# 27
# 36
# 45
# 54
# 63
# 72
# 81

# %%
file.close()
