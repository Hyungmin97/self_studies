# %%
for i in range(10):
  print(f"{i+1}번 반복")
# Out:
# 1번 반복
# 2번 반복
# 3번 반복
# 4번 반복
# 5번 반복
# 6번 반복
# 7번 반복
# 8번 반복
# 9번 반복
# 10번 반복

# %%
리스트 = ['가','나','다','라']

# %%
for i in 리스트:
  print("hi")
# Out:
# hi
# hi
# hi
# hi

# %%
for i in 리스트:
  print(i)
# Out:
# 가
# 나
# 다
# 라

# %%
for i in 리스트:
  print(i + "번 반복")
# Out:
# 가번 반복
# 나번 반복
# 다번 반복
# 라번 반복

# %%
for i in range(0,10):
  print('hi')
# Out:
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
